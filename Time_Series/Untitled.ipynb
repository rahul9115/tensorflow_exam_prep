# %%
import pandas as pd

# %%
df=pd.read_csv("HistoricalQuotes.csv")
df.tail()
# Out:
#       Unnamed: 0        Date   Close/Last     Volume       Open       High  \
# 2513        2513  03/05/2010      31.2786  224647427   $30.7057   $31.3857
# 2514        2514  03/04/2010      30.1014   89591907   $29.8971   $30.1314
# 2515        2515  03/03/2010      29.9043   92846488   $29.8486   $29.9814
# 2516        2516  03/02/2010      29.8357  141486282     $29.99   $30.1186
# 2517        2517  03/01/2010      29.8557  137312041   $29.3928   $29.9286
#
#             Low
# 2513   $30.6614
# 2514   $29.8043
# 2515   $29.7057
# 2516   $29.6771
# 2517     $29.35

# %%
df.columns
# Out:
# Index(['Date', ' Close/Last', ' Volume', ' Open', ' High', ' Low'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Date           0
#  Close/Last    0
#  Volume        0
#  Open          0
#  High          0
#  Low           0
# dtype: int64

# %%
len(df)
# Out:
# 2518

# %%
values=[]
for i in df[" Close/Last"].values:
    values.append(float(i.split("$")[1]))
df[" Close/Last"]=values
df.to_csv("HistoricalQuotes.csv")

# %%
values
# Out:
# [273.36,
#  273.52,
#  292.65,
#  288.08,
#  298.18,
#  313.05,
#  320.3,
#  323.62,
#  319.0,
#  324.95,
#  324.87,
#  327.2,
#  319.61,
#  321.55,
#  320.03,
#  325.21,
#  321.45,
#  318.85,
#  308.66,
#  309.51,
#  323.87,
#  324.34,
#  317.69,
#  308.95,
#  318.31,
#  319.23,
#  317.7,
#  316.57,
#  318.73,
#  315.24,
#  311.34,
#  312.68,
#  316.96,
#  310.33,
#  309.63,
#  303.19,
#  298.39,
#  299.8,
#  297.43,
#  300.35,
#  293.65,
#  291.52,
#  289.8,
#  289.91,
#  284.27,
#  284.0,
#  279.44,
#  280.02,
#  279.74,
#  280.41,
#  279.86,
#  275.15,
#  271.46,
#  270.77,
#  268.48,
#  266.92,
#  270.71,
#  265.58,
#  261.74,
#  259.45,
#  264.16,
#  267.25,
#  267.84,
#  264.29,
#  266.37,
#  261.78,
#  262.01,
#  263.19,
#  266.29,
#  267.1,
#  265.76,
#  262.64,
#  264.47,
#  261.96,
#  262.2,
#  260.14,
#  259.43,
#  257.24,
#  257.13,
#  257.5,
#  255.82,
#  248.76,
#  243.26,
#  243.29,
#  249.05,
#  246.58,
#  243.58,
#  243.18,
#  239.96,
#  240.51,
#  236.41,
# ...

# %%
df.dtypes
# Out:
# Date           object
#  Close/Last    object
#  Volume         int64
#  Open          object
#  High          object
#  Low           object
# dtype: object
